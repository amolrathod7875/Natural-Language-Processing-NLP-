# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer
import string
from textblob import TextBlob

# %%
data = pd.read_csv("tmdb_action_movies.csv")
data.head(3)
# Out:
#                 title                                           overview  \
# 0  Husbands in Action  A detective teams up with his ex-wife's new hu...
# 1      Back in Action  Fifteen years after vanishing from the CIA to ...
# 2      Action Replayy  A young man tries to revive his parents' wilti...
#
#                                      genres release_date  vote_average  \
# 0                      ['Comedy', 'Action']   2026-06-15         7.500
# 1                      ['Action', 'Comedy']   2025-01-15         6.427
# 2  ['Comedy', 'Romance', 'Science Fiction']   2010-11-05         5.172
#
#    popularity
# 0     11.9294
# 1      4.6138
# 2      2.3793

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         200 non-null    str
#  1   overview      188 non-null    str
#  2   genres        200 non-null    str
#  3   release_date  193 non-null    str
#  4   vote_average  200 non-null    float64
#  5   popularity    200 non-null    float64
# dtypes: float64(2), str(4)
# memory usage: 9.5 KB

# %%
data.shape
# Out:
# (200, 6)

# %%
data.select_dtypes(include=str)
# Out:
#                     title                                           overview  \
# 0      Husbands in Action  A detective teams up with his ex-wife's new hu...
# 1          Back in Action  Fifteen years after vanishing from the CIA to ...
# 2          Action Replayy  A young man tries to revive his parents' wilti...
# 3        Last Action Hero  After his father's death, a young boy finds so...
# 4          A Civil Action  Jan Schlickmann is a cynical lawyer who goes o...
# ..                    ...                                                ...
# 195             Re-action                                                NaN
# 196  Net of Heaven Action  A CAT III film directed by Patrick Kong Yeung ...
# 197     First Action Hero  A maverick cop takes on the seedy criminal und...
# 198   Wolf Killing Action                                                NaN
# 199      First Aid Action  Concentrates upon basic first aid steps. Simul...
#
# ...

# %%
data ['title' ] = data['title'].str.lower()

data['overview'] = data['overview'].str.lower()

data['genres'] = data['genres'].str.lower()

# %%
data.isnull().sum()
# Out:
# title            0
# overview        12
# genres           0
# release_date     7
# vote_average     0
# popularity       0
# dtype: int64

# %%
data[data.isna().any(axis=1)]
# Out:
#                                   title  \
# 14                         action women
# 62                               action
# 69   uppukandam brothers back in action
# 124                   cheetah in action
# 129                      action antipub
# 130                           action 13
# 138                         nude action
# 144                     bursting action
# 148              mrs. osei takes action
# 153            the original action hero
# 154                          the action
# 166                        action! 1987
# 167                        early action
# 169                        ready action
# 182                 53 stages of action
# 194                       wolves action
# 195                           re-action
# 198                 wolf killing action
#
#                                               overview  \
# 14                                                 NaN
# 62   exploring transgender and non-binary represent...
# ...

# %%
data.dropna(inplace=True)

# %%
data['genres'].unique()
# Out:
# <StringArray>
# [                               '['comedy', 'action']',
#                                 '['action', 'comedy']',
#             '['comedy', 'romance', 'science fiction']',
#                      '['fantasy', 'action', 'comedy']',
#                                            '['drama']',
#           '['action', 'adventure', 'thriller', 'war']',
#                    '['animation', 'comedy', 'family']',
#                                           '['action']',
#                                  '['comedy', 'drama']',
#                               '['action', 'thriller']',
#                                '['action', 'romance']',
#                        '['drama', 'crime', 'history']',
#                                '['action', 'western']',
#         '['action', 'adventure', 'crime', 'thriller']',
#                                '['drama', 'thriller']',
#                                         '['thriller']',
# ...

# %%
def lower_case(sens):
    return sens.lower()

# %%
column_string = ", ".join(data.columns)

# %%
lower_case(column_string)
# Out:
# 'title, overview, genres, release_date, vote_average, popularity'

# %%
data
# Out:
#                               title  \
# 0                husbands in action
# 1                    back in action
# 2                    action replayy
# 3                  last action hero
# 4                    a civil action
# ..                              ...
# 192  hokusotan 2015 (action direct)
# 193               animals in action
# 196            net of heaven action
# 197               first action hero
# 199                first aid action
#
#                                               overview  \
# 0    a detective teams up with his ex-wife's new hu...
# 1    fifteen years after vanishing from the cia to ...
# 2    a young man tries to revive his parents' wilti...
# 3    after his father's death, a young boy finds so...
# 4    jan schlickmann is a cynical lawyer who goes o...
# ..                                                 ...
# 192  performance by takashi makino with music compo...
# 193  the profession of capturing animals in action ...
# ...

# %%
data['overview'][3]
# Out:
# "after his father's death, a young boy finds solace in action movies featuring an indestructible cop. given a magic ticket by a theater manager, he is transported into the film and teams up with the cop to stop a villain who escapes into the real world."

# %%
data['word_tokenizer'] = data['overview'].apply(sent_tokenize)

# %%
data['word_tokenizer'].apply(' '.join)
# Out:
# 0      a detective teams up with his ex-wife's new hu...
# 1      fifteen years after vanishing from the cia to ...
# 2      a young man tries to revive his parents' wilti...
# 3      after his father's death, a young boy finds so...
# 4      jan schlickmann is a cynical lawyer who goes o...
#                              ...
# 192    performance by takashi makino with music compo...
# 193    the profession of capturing animals in action ...
# 196    a cat iii film directed by patrick kong yeung ...
# 197    a maverick cop takes on the seedy criminal und...
# 199    concentrates upon basic first aid steps. simul...
# Name: word_tokenizer, Length: 182, dtype: str

# %%
data['word_tokenizer'][3]
# Out:
# ["after his father's death, a young boy finds solace in action movies featuring an indestructible cop.",
#  'given a magic ticket by a theater manager, he is transported into the film and teams up with the cop to stop a villain who escapes into the real world.']

# %%
data.head(3)
# Out:
#                 title                                           overview  \
# 0  husbands in action  a detective teams up with his ex-wife's new hu...
# 1      back in action  fifteen years after vanishing from the cia to ...
# 2      action replayy  a young man tries to revive his parents' wilti...
#
#                                      genres release_date  vote_average  \
# 0                      ['comedy', 'action']   2026-06-15         7.500
# 1                      ['action', 'comedy']   2025-01-15         6.427
# 2  ['comedy', 'romance', 'science fiction']   2010-11-05         5.172
#
#    popularity                                     word_tokenizer
# 0     11.9294  [a detective teams up with his ex-wife's new h...
# 1      4.6138  [fifteen years after vanishing from the cia to...
# 2      2.3793  [a young man tries to revive his parents' wilt...
