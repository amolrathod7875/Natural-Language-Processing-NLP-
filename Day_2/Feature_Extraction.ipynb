# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.DataFrame({"text" : ['people watch campusX', "compusX watch people", "people write comment", "comment write people"], "ouptut":[1,1,0,0]})

# %%
df
# Out:
#                    text  ouptut
# 0  people watch campusX       1
# 1  compusX watch people       1
# 2  people write comment       0
# 3  comment write people       0

# %%
cv = CountVectorizer(ngram_range=(1,2))
bow = cv.fit_transform(df['text'])

# %%
cv.vocabulary_
# Out:
# {'people': 5,
#  'watch': 8,
#  'campusx': 0,
#  'people watch': 6,
#  'watch campusx': 9,
#  'compusx': 3,
#  'compusx watch': 4,
#  'watch people': 10,
#  'write': 11,
#  'comment': 1,
#  'people write': 7,
#  'write comment': 12,
#  'comment write': 2,
#  'write people': 13}
