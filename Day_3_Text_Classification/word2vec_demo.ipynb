# %%
! pip install wget
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=bd24525a89ac88a8f22281134026790e38fdcc6d4b400530c7b15342a79bff24
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import wget
import numpy as np

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")
# Out:
# [===============-----------------------------------] 31.5% 523.3/1662.8MB downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6191/3971408409.py in <cell line: 0>()
#       1 import gensim.downloader as api
# ----> 2 model = api.load("word2vec-google-news-300")
#
# /usr/local/lib/python3.12/dist-packages/gensim/downloader.py in load(name, return_path)
#     494     path = os.path.join(folder_dir, file_name)
#     495     if not os.path.exists(folder_dir):
# --> 496         _download(name)
#     497
#     498     if return_path:
#
# /usr/local/lib/python3.12/dist-packages/gensim/downloader.py in _download(name)
#     394         fname = "{fname}.gz".format(fname=name)
#     395         dst_path = os.path.join(tmp_dir, fname)
# --> 396         urllib.urlretrieve(url_data, dst_path, reporthook=_progress)
# ...

# %%
model['man'].shape
# Out:
# (300,)

# %%
# !python --version
# Out:
# Python 3.11.15

# %%
model.similar_by_vector('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.similar_by_word('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.similarity('man','women')
# Out:
# 0.2883053

# %%
model.similarity('man','makeup')
# Out:
# 0.051851716

# %%
model.similarity('man','car')
# Out:
# 0.2407355

# %%
model.doesnt_match(['man','money','women'])
# Out:
# 'money'

# %%
vec = model['man'] - model['women'] + model['money']

# %%
model.most_similar(vec)
# Out:
# [('money', 0.647374153137207),
#  ('man', 0.4702134430408478),
#  ('monies', 0.4281834363937378),
#  ('grubstake', 0.42208266258239746),
#  ('cash', 0.4136449992656708),
#  ('notoriously_frugal', 0.4135630428791046),
#  ('dollars', 0.39147061109542847),
#  ('moneybag', 0.3912982642650604),
#  ('funds', 0.390668123960495),
#  ('moneys', 0.389777272939682)]
